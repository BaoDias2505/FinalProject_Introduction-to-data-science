# %% [markdown]
# <div style="text-align: center; background-color: #0A6EBD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Final project - Introduction to DS
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 4.0 - Data modelling
# </div>

# %% [markdown]
# ## Problem statement

# %% [markdown]
# Sử dụng dữ liệu thu thập được để tạo một hệ thống đề xuất video thông qua một đoạn văn mà người dùng nhập vào công cụ tìm kiếm (giống như chúng ta đang bắt chước hệ thống đề xuất của youtube).
#
# Giải quyết bài toán này sẽ giúp ích cho cả người dùng và nền tảng phát sóng:
# - Đôi khi người dùng muốn xem một video nào đó nhưng họ lại không biết nên chọn cái nào trong vô số video hiện có. Khi này, hệ thống đề xuất của chúng ta sẽ gợi ý những video mà người dùng có thể muốn xem nhất thông qua đoạn văn bản mà người dùng nhập vào công cụ tìm kiếm. Khi này, người dùng sẽ có được trải nghiệm sử dụng dịch vụ tốt hơn, đỡ mất nhiều công sức, thời gian để xem thử từng video khác nhau, v.v.
# - Với nền tảng phát sóng, việc đề xuất được những video mà người dùng muốn xem sẽ giúp khách hàng sử dụng dịch vụ của họ nhiều hơn. Tất nhiên, có càng nhiều người dùng thì ta sẽ có càng nhiều doanh thu. Ngoài ra, nếu thực sự cần thiết, ta có thể sử dụng số liệu thống kê đó để đi gọi vốn từ các doanh nghiệp lớn, nhằm phát triển các dự án khác trong tương lai.

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import re


# Visualization libraries
import tqdm # Show progress bar
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# NLP libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
from nltk.tokenize import RegexpTokenizer

# Sklearn model and util functions
import sklearn
from sklearn.model_selection import train_test_split, KFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans, MiniBatchKMeans, BisectingKMeans
from sklearn import metrics

# Util libraries
from typing import Dict, List, Any
import itertools
import pickle # Save/Load model parameters

SEED = 2023
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Read clean data

# %%
clean_df = pd.read_csv('../data/processed/video_data_processed.csv')

# %%
# clean_df.sample(5)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Clean the video title

# %%
clean_df['title'].head(5)
# Out:
# 0                          My top 50 scikit-learn tips
# 1                                21 more pandas tricks
# 2    Adapt this pattern to solve many Machine Learn...
# 3    Tune multiple models simultaneously with GridS...
# 4              Access part of a Pipeline using slicing
# Name: title, dtype: object

# %%
# Preprocess the data: convert to lowercase, remove special characters, and stopwords
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = [token for token in text.split() if token not in stop_words]
    return ' '.join(tokens)

clean_df['clean_title'] = clean_df['title'].apply(preprocess_text)
# clean_df['clean_title'] = clean_df['clean_title'] + "|" + clean_df['video_id']

# %%
clean_df['clean_title'].head(5)
# Out:
# 0                                 top scikitlearn tips
# 1                                        pandas tricks
# 2    adapt pattern solve many machine learning prob...
# 3     tune multiple models simultaneously gridsearchcv
# 4                   access part pipeline using slicing
# Name: clean_title, dtype: object

# %% [markdown]
# Create a TF-IDF vectorizer

# %%
# Create a TF-IDF vectorizer to vectorize the text
# Reference: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
vectorizer = TfidfVectorizer(lowercase=True, stop_words='english',
                             max_features=20_000, # !reduce number of features
                             dtype=np.float32)
vectorizer.fit(clean_df['clean_title'])
# Out:
# TfidfVectorizer(dtype=<class 'numpy.float32'>, max_features=20000,
#                 stop_words='english')

# %% [markdown]
# Split data into training, validating and testing set

# %%
# Split the data into `train` and `vaild + test` sets
train_data, temp_data = train_test_split(clean_df['clean_title'], 
                                         test_size=0.2, random_state=SEED)
# Further split the temporary set into validation and test sets
valid_data, test_data = train_test_split(temp_data,
                                         test_size=0.5, random_state=SEED)

# %% [markdown]
# ## Baseline Model Comparison

# %%
# Define a dictionary to store clustering models
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.cluster
baseline_parameters = {
    "n_clusters": 5, "init": "k-means++", 
    "n_init": 1, "random_state": SEED,
}
baseline_models = {
    'KMeans': KMeans(**baseline_parameters),
    'BisectingKMeans': BisectingKMeans(**baseline_parameters),
    'MiniBatchKMeans': MiniBatchKMeans(**baseline_parameters),
}

# Define K-Fold cross-validation
# Reference: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html
K_FOLDS = 5
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Store the history of cross-validation process
entries = []

# Do k-fold cross validation
for i, (train_ids, valid_ids) in enumerate(kfold.split(train_data), start=1):
    # Check for duplicates index in `train_ids` and `valid_ids`
    assert len(set(train_ids).intersection(set(valid_ids))) == 0

    # Convert text to numerical data using TF-IDF
    data_to_train = vectorizer.transform(train_data.iloc[train_ids])
    data_to_valid = vectorizer.transform(train_data.iloc[valid_ids])

    print(f"\n------------------ Fold {i} ------------------")
    for model_name, model in baseline_models.items():
        print(f"{model_name.rjust(15)}: Fitting... ", end="")
        
        # Fit the model to the training data
        model.fit(data_to_train)

        # Evaluate the model on the validation data
        # Reference: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html#sklearn.metrics.silhouette_score
        print(f"-> Evaluating...")
        labels_pred = model.predict(data_to_valid)
        silhouette_score \
            = metrics.silhouette_score(data_to_valid, 
                                       labels_pred, metric='euclidean')

        # Add new record to the history
        entries.append([model_name, i, silhouette_score])

# Create a dataframe to store the results
cross_validation_df = pd.DataFrame(
    data=entries,
    columns=["model_name", "fold_id", "silhouette_score"]
)
# ~ 3min
# Out:
# ------------------ Fold 1 ------------------
#          KMeans: Fitting... -> Evaluating...
# BisectingKMeans: Fitting... -> Evaluating...
# MiniBatchKMeans: Fitting... -> Evaluating...
#
# ------------------ Fold 2 ------------------
#          KMeans: Fitting... -> Evaluating...
# BisectingKMeans: Fitting... -> Evaluating...
# MiniBatchKMeans: Fitting... -> Evaluating...
#
# ------------------ Fold 3 ------------------
#          KMeans: Fitting... -> Evaluating...
# BisectingKMeans: Fitting... -> Evaluating...
# MiniBatchKMeans: Fitting... -> Evaluating...
#
# ------------------ Fold 4 ------------------
#          KMeans: Fitting... -> Evaluating...
# BisectingKMeans: Fitting... -> Evaluating...
# MiniBatchKMeans: Fitting... -> Evaluating...
#
# ------------------ Fold 5 ------------------
#          KMeans: Fitting... -> Evaluating...
# BisectingKMeans: Fitting... -> Evaluating...
# MiniBatchKMeans: Fitting... -> Evaluating...

# %% [markdown]
# Visualize the results

# %%
# Plot the results
sns.boxplot(x='model_name', y='silhouette_score', hue='model_name',
            data=cross_validation_df, showmeans=True,
            palette=sns.color_palette()[:baseline_models.__len__()],
            # Reference: https://matplotlib.org/stable/api/markers_api.html
            meanprops={"marker":"^","markerfacecolor":"white", 
                       "markeredgecolor":"black", "markersize":"10"}
            )
plt.title(f"Boxplot of Base-Line Model Performance using {K_FOLDS}-Fold cross validation",
          fontsize=12, fontweight="bold")
plt.xlabel("Model Name", fontsize=10)
plt.ylabel("Silhouette Score", fontsize=10)
plt.xticks(rotation=20)
plt.show();

# %% [markdown]
# Summarize the results

# %%
# Summarize the results
baseline_results = \
    cross_validation_df.groupby('model_name')["silhouette_score"]\
        .agg(['mean', 'std']).sort_values(by='mean', ascending=False)

# Add metric names
baseline_results.columns.name = "silhouette_score"

baseline_results
# Out:
# silhouette_score      mean       std
# model_name
# MiniBatchKMeans   0.008726  0.001073
# KMeans            0.007307  0.001749
# BisectingKMeans   0.007125  0.002312

# %% [markdown]
# > Nhận xét: `MiniBatchKMeans` là "baseline model" chạy tốt nhất trên tập dữ liệu `train_data`. Ở bước tiếp theo, ta cần thực hiện "Hyper-parameter Tuning" để giúp các model tạo ra kết quả tốt hơn nữa.

# %% [markdown]
# ## Hyper-parameter Tuning

# %% [markdown]
# ### Getting the optimal number of clusters

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# # Reference: https://www.geeksforgeeks.org/determining-the-number-of-clusters-in-data-mining/
# # Determining the maximum number of clusters using the simple method
# limit = int((clean_df.shape[0]//2)**0.5)
# K = list(range(limit, limit-10, -1))

K = list(range(3, 25, 1))
data = vectorizer.transform(train_data)

# wcss - within cluster sum of squared distances
wcss_df = pd.DataFrame(columns=['n_clusters', 'model_name', 'wcss'])
models = {
    'KMeans': KMeans,
    'BisectingKMeans': BisectingKMeans,
    'MiniBatchKMeans': MiniBatchKMeans,
}

with tqdm.tqdm(total=len(K)) as pbar:
    pbar.set_description("Elbow Method is in progress...")
    for n_clusters in K:
        for model_name, model_prototype in models.items():
            model = model_prototype(n_clusters=n_clusters, random_state=SEED,
                                    init='k-means++', n_init=1)
            model.fit(data)
            wcss_df.loc[len(wcss_df)] = [n_clusters, model_name, model.inertia_]
        
        pbar.update(1)

# ~ 8min
# Out:
# Elbow Method is in progress...: 100%|██████████| 22/22 [02:13<00:00,  6.05s/it]

# %% [markdown]
# Visualize the results

# %%
colors = ['blue', 'orangered', 'green']
for i, model_name in enumerate(models.keys()):
    ax = wcss_df.query(f"model_name == '{model_name}'").plot.line(
        x='n_clusters', y='wcss', figsize=(10, 6),
        marker='o', color=colors[i], linewidth=1,
        legend=False,
    )
    ax.set_xticks(K)
    ax.set_title(f"Elbow Method for \'{model_name}\' model",
                 fontdict={'fontsize': 14, 'fontweight': 'bold'})
    ax.set_xlabel("Number of Clusters (K)")
    ax.set_ylabel("Within Cluster Sum of Squared Distances (WCSS)")

# %% [markdown]
# > <u>**Nhận xét**</u>: Quan sát các biểu đồ trên, ta thấy rằng các tham số `n_clusters` nên được sử dụng để tinh chỉnh từng mô hình là:
# > - KMeans: `[8, 11, 17, 20]`
# > - BisectingKMeans: `[7, 11, 12, 15, 17]`
# > - MiniBatchKMeans: `[6, 11, 15, 18, 20]`

# %% [markdown]
# ### For the other hyper-parameters

# %%
def _hyperParameters_tuning(model: sklearn.cluster, 
                            hyperParams_grid: Dict[str, List]) -> Dict[str, Any]:
    best_score: float = 0.0
    best_hyperParams: Dict[str, Any] = None

    # Get all combinations
    all_combinations = list(itertools.product(*hyperParams_grid.values()))

    # Create a list of dictionaries for each combination
    hyperParams_combinations = [dict(zip(hyperParams_grid.keys(), combination)) 
                                for combination in all_combinations]

    # Convert text to numerical data using TF-IDF
    _data_to_train = vectorizer.transform(train_data)
    _data_to_valid = vectorizer.transform(valid_data)

    print(f"========== Fine-tuning '{model.__class__.__name__}' on total {len(hyperParams_combinations)} hyper-parameter combinations ==========")
    for i, hyperParams in enumerate(hyperParams_combinations,start=1):
        # Set hyperparameters
        model.set_params(**hyperParams)
        
        # Fit the model to the training data
        print(f"Fitting on combination {str(i).rjust(2)}...", end="")
        model.fit(_data_to_train)
        
        # Evaluate the model on the validation data
        print(f" -> Evaluating...", end="")
        pred = model.predict(_data_to_valid)
        score = metrics.silhouette_score(_data_to_valid, pred, metric='euclidean')

        if score > best_score:
            print(f" -> Get new best-score: {score:.6f}, updating best-hyper-parameters...")
            best_score = score
            best_hyperParams = hyperParams
        else:
            print(f" -> Best-score remains: {best_score:.6f}")
            
    return best_hyperParams

# %% [markdown]
# #### KMeans

# %%
kmeans_best_hyperParams = _hyperParameters_tuning(KMeans(), {
    'verbose': [0],
    'random_state': [SEED],
    'max_iter': [300],
    'n_init': [3],
    'tol': [1e-6],
    
    'init': ['k-means++', 'random'],
    'algorithm': ['lloyd', 'elkan'],
    # 'n_clusters': [6, 7, 11, 12, 16],
    'n_clusters': [8, 11, 17, 20],
}) # ~ 10min
# Out:
# ========== Fine-tuning 'KMeans' on total 16 hyper-parameter combinations ==========
# Fitting on combination  1... -> Evaluating... -> Get new best-score: 0.009938, updating best-hyper-parameters...
# Fitting on combination  2... -> Evaluating... -> Get new best-score: 0.010318, updating best-hyper-parameters...
# Fitting on combination  3... -> Evaluating... -> Get new best-score: 0.015240, updating best-hyper-parameters...
# Fitting on combination  4... -> Evaluating... -> Best-score remains: 0.015240
# Fitting on combination  5... -> Evaluating... -> Best-score remains: 0.015240
# Fitting on combination  6... -> Evaluating... -> Best-score remains: 0.015240
# Fitting on combination  7... -> Evaluating... -> Best-score remains: 0.015240
# Fitting on combination  8... -> Evaluating... -> Get new best-score: 0.015887, updating best-hyper-parameters...
# Fitting on combination  9... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 10... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 11... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 12... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 13... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 14... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 15... -> Evaluating... -> Best-score remains: 0.015887
# Fitting on combination 16... -> Evaluating... -> Best-score remains: 0.015887

# %%
# TEST
kmeans_best_hyperParams
# Out:
# {'verbose': 0,
#  'random_state': 2023,
#  'max_iter': 300,
#  'n_init': 3,
#  'tol': 1e-06,
#  'init': 'k-means++',
#  'algorithm': 'elkan',
#  'n_clusters': 20}

# %% [markdown]
# #### BisectingKMeans

# %%
bisecting_kmeans_best_hyperParams = \
    _hyperParameters_tuning(BisectingKMeans(), {
        'verbose': [0],
        'random_state': [SEED],
        'max_iter': [300],
        'n_init': [3],
        'tol': [1e-6],
        
        'init': ['k-means++', 'random'],
        'algorithm': ['lloyd', 'elkan'],
        'bisecting_strategy': ['biggest_inertia', 'largest_cluster'],
        'n_clusters': [7, 11, 12, 15, 17],
    }) # ~ 22min
# Out:
# ========== Fine-tuning 'BisectingKMeans' on total 40 hyper-parameter combinations ==========
# Fitting on combination  1... -> Evaluating... -> Get new best-score: 0.009670, updating best-hyper-parameters...
# Fitting on combination  2... -> Evaluating... -> Get new best-score: 0.011994, updating best-hyper-parameters...
# Fitting on combination  3... -> Evaluating... -> Get new best-score: 0.012034, updating best-hyper-parameters...
# Fitting on combination  4... -> Evaluating... -> Get new best-score: 0.012718, updating best-hyper-parameters...
# Fitting on combination  5... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination  6... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination  7... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination  8... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination  9... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 10... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 11... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 12... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 13... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 14... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 15... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 16... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 17... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 18... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 19... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 20... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 21... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 22... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 23... -> Evaluating... -> Best-score remains: 0.012718
# Fitting on combination 24... -> Evaluating... -> Get new best-score: 0.014209, updating best-hyper-parameters...
# Fitting on combination 25... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 26... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 27... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 28... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 29... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 30... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 31... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 32... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 33... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 34... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 35... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 36... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 37... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 38... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 39... -> Evaluating... -> Best-score remains: 0.014209
# Fitting on combination 40... -> Evaluating... -> Best-score remains: 0.014209

# %%
# TEST
bisecting_kmeans_best_hyperParams
# Out:
# {'verbose': 0,
#  'random_state': 2023,
#  'max_iter': 300,
#  'n_init': 3,
#  'tol': 1e-06,
#  'init': 'random',
#  'algorithm': 'lloyd',
#  'bisecting_strategy': 'biggest_inertia',
#  'n_clusters': 15}

# %% [markdown]
# #### MiniBatchKMeans

# %%
minibatch_kmeans_best_hyperParams = \
    _hyperParameters_tuning(MiniBatchKMeans(), {
        'verbose': [0],
        'random_state': [SEED],
        'max_iter': [300],
        'n_init': [10],
        'tol': [0.0],
        'init_size': [None],
        'batch_size': [1024],
        
        'init': ['k-means++', 'random'],
        'max_no_improvement': [10, 20],
        'reassignment_ratio': [0.01, 0.001],
        # 'n_clusters': [6, 7, 8, 11, 17],
        'n_clusters': [6, 11, 15, 18, 20],
        
    }) # ~ 4min
# Out:
# ========== Fine-tuning 'MiniBatchKMeans' on total 40 hyper-parameter combinations ==========
# Fitting on combination  1... -> Evaluating... -> Get new best-score: 0.007332, updating best-hyper-parameters...
# Fitting on combination  2... -> Evaluating... -> Get new best-score: 0.011916, updating best-hyper-parameters...
# Fitting on combination  3... -> Evaluating... -> Get new best-score: 0.014161, updating best-hyper-parameters...
# Fitting on combination  4... -> Evaluating... -> Best-score remains: 0.014161
# Fitting on combination  5... -> Evaluating... -> Get new best-score: 0.015980, updating best-hyper-parameters...
# Fitting on combination  6... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination  7... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination  8... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination  9... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 10... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 11... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 12... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 13... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 14... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 15... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 16... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 17... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 18... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 19... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 20... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 21... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 22... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 23... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 24... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 25... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 26... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 27... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 28... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 29... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 30... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 31... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 32... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 33... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 34... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 35... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 36... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 37... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 38... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 39... -> Evaluating... -> Best-score remains: 0.015980
# Fitting on combination 40... -> Evaluating... -> Best-score remains: 0.015980

# %%
# TEST
minibatch_kmeans_best_hyperParams
# Out:
# {'verbose': 0,
#  'random_state': 2023,
#  'max_iter': 300,
#  'n_init': 10,
#  'tol': 0.0,
#  'init_size': None,
#  'batch_size': 1024,
#  'init': 'k-means++',
#  'max_no_improvement': 10,
#  'reassignment_ratio': 0.01,
#  'n_clusters': 20}

# %% [markdown]
# ## Training models and evaluation

# %% [markdown]
# Create models with the best hyper-parameters and save them for future use

# %%
# Get the best model
best_kmeans_model = KMeans(**kmeans_best_hyperParams)
best_bisecting_kmeans_model = BisectingKMeans(**bisecting_kmeans_best_hyperParams)
best_minibatch_kmeans_model = MiniBatchKMeans(**minibatch_kmeans_best_hyperParams)

best_models = {
    'best_kmeans_model': best_kmeans_model,
    'best_bisecting_kmeans_model': best_bisecting_kmeans_model,
    'best_minibatch_kmeans_model': best_minibatch_kmeans_model,
}

# Save the best model for later use
# Reference: https://stackoverflow.com/questions/54879434/how-to-use-pickle-to-save-sklearn-model
for model_name, model in best_models.items():
    with open(f"../data/models/{model_name}.pkl", "wb") as f:
        pickle.dump(model, f)

# %% [markdown]
# Load models if needed

# %%
best_models_lst = ['best_kmeans_model', 'best_bisecting_kmeans_model', 'best_minibatch_kmeans_model']
best_models = {}
# Load model if needed
for model_name in best_models_lst:
    with open(f"../data/models/{model_name}.pkl", "rb") as f:
        best_models[model_name] = pickle.load(f)
        print(f"[LOG] Loaded model '{model_name}'")
        print(best_models[model_name].get_params(),end="\n\n")

print(f">> Total number of models: {best_models.__len__()}")
# Out:
# [LOG] Loaded model 'best_kmeans_model'
# {'algorithm': 'elkan', 'copy_x': True, 'init': 'k-means++', 'max_iter': 300, 'n_clusters': 20, 'n_init': 3, 'random_state': 2023, 'tol': 1e-06, 'verbose': 0}
#
# [LOG] Loaded model 'best_bisecting_kmeans_model'
# {'algorithm': 'lloyd', 'bisecting_strategy': 'biggest_inertia', 'copy_x': True, 'init': 'random', 'max_iter': 300, 'n_clusters': 15, 'n_init': 3, 'random_state': 2023, 'tol': 1e-06, 'verbose': 0}
#
# [LOG] Loaded model 'best_minibatch_kmeans_model'
# {'batch_size': 1024, 'compute_labels': True, 'init': 'k-means++', 'init_size': None, 'max_iter': 300, 'max_no_improvement': 10, 'n_clusters': 20, 'n_init': 10, 'random_state': 2023, 'reassignment_ratio': 0.01, 'tol': 0.0, 'verbose': 0}
#
# >> Total number of models: 3

# %% [markdown]
# (Re-)Train models on (`training + validating` set) and evaluate them on `testing` set

# %%
model_name_logs = {
    'best_kmeans_model': '================ best_kmeans_model ================',
    'best_bisecting_kmeans_model': '=========== best_bisecting_kmeans_model ===========',
    'best_minibatch_kmeans_model': '=========== best_minibatch_kmeans_model ===========',
}
model_prototypes = {
    'best_kmeans_model': KMeans,
    'best_bisecting_kmeans_model': BisectingKMeans,
    'best_minibatch_kmeans_model': MiniBatchKMeans,
}

# Store the result to dateframe
# history_df = pd.DataFrame(columns=["model_name", "n_init", "score"])
history_df = pd.DataFrame(columns=["model_name", "max_iter", 
                                   "training_score", "testing_score"])

# Combine train and validation data
final_train_data = pd.concat([train_data, valid_data], axis=0)

# Convert text to numerical data using TF-IDF
data_to_train = vectorizer.transform(final_train_data)
data_to_test = vectorizer.transform(test_data)

MAX_ITERS = range(2,29,2)
for model_name, model in best_models.items():
    if model_name not in model_name_logs.keys():
        continue
    print(f"{model_name_logs[model_name]}\n")
    for max_iter in MAX_ITERS:
        # Create a new model using the best hyper-parameters
        model = model_prototypes[model_name]\
                    (**best_models[model_name].get_params())
        
        # Update parameters of new model
        model.random_state = SEED
        model.n_init = 1
        model.max_iter = max_iter
    
        # Fit each model on `data_to_train`
        model.fit(data_to_train)
        training_score = model.inertia_
        
        # Evalute model on `data_to_test`
        pred = model.predict(data_to_test)
        testing_score = metrics.silhouette_score(data_to_test, pred)
        
        # LOG
        # print(f"`max_iter` = {str(max_iter).rjust(2)} -> score: {score}")
        print(f"`max_iter` = {max_iter}\n-------------------------------")
        print(f"Training score: {training_score}")
        print(f"Testing score: {testing_score}", end="\n\n")
    
        # Update history
        history_df.loc[len(history_df)] \
            = [model_name, max_iter, training_score, testing_score]

# ~20min
# Out:
# ================ best_kmeans_model ================
#
# `max_iter` = 2
# -------------------------------
# Training score: 50780.61328125
# Testing score: 0.015387640334665775
#
# `max_iter` = 4
# -------------------------------
# Training score: 50714.97265625
# Testing score: 0.015415078960359097
#
# `max_iter` = 6
# -------------------------------
# Training score: 50701.9765625
# Testing score: 0.015471446327865124
#
# `max_iter` = 8
# -------------------------------
# Training score: 50700.3984375
# Testing score: 0.015432107262313366
#
# `max_iter` = 10
# -------------------------------
# Training score: 50699.1640625
# Testing score: 0.015405110083520412
#
# `max_iter` = 12
# -------------------------------
# Training score: 50698.4453125
# Testing score: 0.0153769226744771
#
# `max_iter` = 14
# -------------------------------
# Training score: 50698.45703125
# Testing score: 0.0153769226744771
#
# `max_iter` = 16
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# `max_iter` = 18
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# `max_iter` = 20
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# `max_iter` = 22
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# `max_iter` = 24
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# `max_iter` = 26
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# `max_iter` = 28
# -------------------------------
# Training score: 50698.4375
# Testing score: 0.015374424867331982
#
# =========== best_bisecting_kmeans_model ===========
#
# `max_iter` = 2
# -------------------------------
# Training score: 51998.6484375
# Testing score: 0.007455200422555208
#
# `max_iter` = 4
# -------------------------------
# Training score: 51699.890625
# Testing score: 0.00873728096485138
#
# `max_iter` = 6
# -------------------------------
# Training score: 51686.640625
# Testing score: 0.010837264358997345
#
# `max_iter` = 8
# -------------------------------
# Training score: 51589.92578125
# Testing score: 0.011140265502035618
#
# `max_iter` = 10
# -------------------------------
# Training score: 51664.8046875
# Testing score: 0.010433133691549301
#
# `max_iter` = 12
# -------------------------------
# Training score: 51566.7265625
# Testing score: 0.011700698174536228
#
# `max_iter` = 14
# -------------------------------
# Training score: 51470.36328125
# Testing score: 0.01172408927232027
#
# `max_iter` = 16
# -------------------------------
# Training score: 51378.9140625
# Testing score: 0.012588177807629108
#
# `max_iter` = 18
# -------------------------------
# Training score: 51422.57421875
# Testing score: 0.01285471860319376
#
# `max_iter` = 20
# -------------------------------
# Training score: 51456.7734375
# Testing score: 0.011113430373370647
#
# `max_iter` = 22
# -------------------------------
# Training score: 51456.7734375
# Testing score: 0.011113430373370647
#
# `max_iter` = 24
# -------------------------------
# Training score: 51456.7734375
# Testing score: 0.011113430373370647
#
# `max_iter` = 26
# -------------------------------
# Training score: 51456.7734375
# Testing score: 0.011113430373370647
#
# `max_iter` = 28
# -------------------------------
# Training score: 51456.765625
# Testing score: 0.011113430373370647
#
# =========== best_minibatch_kmeans_model ===========
#
# `max_iter` = 2
# -------------------------------
# Training score: 50762.62890625
# Testing score: 0.016429712995886803
#
# `max_iter` = 4
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 6
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 8
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 10
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 12
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 14
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 16
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 18
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 20
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 22
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 24
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 26
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084
#
# `max_iter` = 28
# -------------------------------
# Training score: 50757.1328125
# Testing score: 0.016410382464528084

# %%
# Save the result
# history_df.to_csv("history.csv", index=False)
history_df = pd.read_csv("history.csv")

# %% [markdown]
# ## Results analysis

# %% [markdown]
# Visualize the results

# %%
# Visualize the results
MAX_ITERS = range(2,29,2)
colors = ['blue', 'orangered', 'green']
for i, model_name in enumerate(best_models.keys()):
    ax = history_df.query(f"model_name == '{model_name}'").plot.line(
        x='max_iter', y='testing_score', figsize=(10, 5),
        marker='o', color=colors[i], linewidth=1,
        legend=False,
    )
    ax.set_xticks(MAX_ITERS)
    ax.set_title(f"Evaluation report for \'{model_name}\' model",
                 fontdict={'fontsize': 14, 'fontweight': 'bold'})
    ax.set_xlabel("Number of \'max_iter\'")
    ax.set_ylabel("Silhouette score")

# %% [markdown]
# Summarize the results

# %%
# Summarize the results
eval_results = \
    history_df.groupby('model_name')["testing_score"]\
        .agg(['mean', 'std']).sort_values(by='mean', ascending=False)

# Add metric names
eval_results.columns.name = "silhouette_score"

eval_results
# Out:
# silhouette_score                 mean       std
# model_name
# best_minibatch_kmeans_model  0.016412  0.000005
# best_kmeans_model            0.015392  0.000029
# best_bisecting_kmeans_model  0.010931  0.001388

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Như vậy, `best_minibatch_kmeans_model` là mô hình hoạt động tốt nhất trên tập dữ liệu của chúng ta. Do đó, ta sẽ tận dụng mô hình này để giải quyết bài toán đã đề ra ban đầu.

# %% [markdown]
# ## Clustering all video titles

# %% [markdown]
# Define `my_best_model` and optimize it

# %%
# Define the best model
best_model_name = 'best_minibatch_kmeans_model'
my_best_model = None
with open(f"../data/models/{best_model_name}.pkl", "rb") as f:
    my_best_model = pickle.load(f)
    # print(f"[LOG] Loaded model '{best_model_name}'")

# Display the best model
my_best_model
# Out:
# MiniBatchKMeans(max_iter=300, n_clusters=20, n_init=10, random_state=2023)

# %%
# Optimize the model
my_best_model.n_init = 10

# %%
# TEST
my_best_model.get_params()
# Out:
# {'batch_size': 1024,
#  'compute_labels': True,
#  'init': 'k-means++',
#  'init_size': None,
#  'max_iter': 300,
#  'max_no_improvement': 10,
#  'n_clusters': 20,
#  'n_init': 10,
#  'random_state': 2023,
#  'reassignment_ratio': 0.01,
#  'tol': 0.0,
#  'verbose': 0}

# %% [markdown]
# Train `my_best_model` on all video data in dataset

# %%
# Combine train, validation and test data
all_video_data = pd.concat((train_data, valid_data, test_data), axis=0)

# Convert text to numerical data using TF-IDF
data = vectorizer.transform(all_video_data)

# Train the model on all data
my_best_model.fit(data)

# Get the labels (cluster_id) of all data
labels = my_best_model.predict(data)
# ~ 4min

# %% [markdown]
# Use prediction result to assign `cluster_id` to each video in dataset

# %%
video_cluster_df = pd.DataFrame({
    'index': all_video_data.index,
    'cluster_id': labels
})

# %%
merged_df = pd.merge(left=video_cluster_df, right=clean_df, 
                     left_on='index', right_index=True)

# %% [markdown]
# Drop unnecessary columns

# %%
# Drop unnecessary columns
unnecessary_cols = ['index', 'clean_title', 'publishedAt.hour', 'publishedAt.day', 
                    'publishedAt.year', 'publishedAt.month']
merged_df.drop(columns=unnecessary_cols, inplace=True)

# %%
# TEST
merged_df.sample(3)
# Out:
#        cluster_id     video_id              channelTitle  \
# 26344           7  Do1wq8QpgvU                deeplizard
# 24312          15  pSci9TgJ4uM  Analytics India Magazine
# 2983           16  IZRe0nwkuXc          Alex The Analyst
#
#                                                    title  \
# 26344  Hidden Layers 🌌 - Beginner Lesson in Deep Lear...
# 24312  Krishna Mohan & Nitin Hosurkar at Cypher 2016-...
# 2983   Data Analyst Q/A #6 | Why Am I Not a Data Scie...
#
#                                              description  \
# 26344  👉 Find out more and enroll in the Deep Learnin...
# 24312  SPEAKER: Krishna Mohan, Sr. Manager, Technolog...
# 2983   Today I answer some of your Data Analyst Quest...
#
#                                                     tags  \
# 26344  deep learning|pytorch|cuda|gpu|cudnn|nvidia|tr...
# 24312                                            (notag)
# 2983   Data Analyst|Data Analyst job|Data Analyst Car...
#
#                      publishedAt  viewCount  likeCount  commentCount  \
# 26344  2023-11-19 17:00:16+00:00        366         17             1
# 24312  2016-09-27 10:30:41+00:00        120          1             0
# 2983   2021-04-15 11:00:06+00:00      21989        822           149
#
#        duration definition  caption  publishedAt.dayOfWeek  \
# 26344        58         hd    False                      6
# 24312       773         sd    False                      1
# 2983       1145         hd    False                      3
#
#        publishedAt.weekOfYear
# 26344                      46
# 24312                      39
# 2983                       15

# %%
# Save final data for later use
merged_df.to_csv('../data/processed/video_data_clustered.csv', index=False)

# Save the model for later use
with open("../data/models/my_best_model.pkl", "wb") as f:
    pickle.dump(my_best_model, f)

# %% [markdown]
# ## Prediction

# %% [markdown]
# Assign `cluster_id` for new text data

# %%
# Assuming 'new_data' is a list of new video titles
new_data = ["Tech news and updates",
            "Learn Python in fast and easy way",
            "Machine learning explained in 5 minutes",
            "How to become a Data Analyst",
            ]

new_data = pd.Series(new_data)
text_values = new_data.apply(preprocess_text)

# Transform the preprocessed new data into TF-IDF features using the same vectorizer
new_tfidf_matrix = vectorizer.transform(text_values)

# Use the trained k-means model to predict cluster labels for the new data
pred_labels = my_best_model.predict(new_tfidf_matrix)

# %% [markdown]
# ##### Recommend top `n` video titles in the same cluster

# %%
# Return top `n` video titles in the same cluster
def _recommend_top_n_videos(cluster_id, top_n: int = 10) -> pd.DataFrame:
    metric_to_sort = 'viewCount'
    
    # Define a dataframe to store the recommended videos
    recommended_videos = pd.DataFrame(columns=['channelTitle', 'title'])
    # !USING THE BELOW CODE FOR TESTING
    # recommended_videos = pd.DataFrame(columns=['channelTitle', 'title', 'viewCount'])
    
    # Define a set to store the channels that have been recommended
    set_of_channels = set()
    
    # Get all videos in the same cluster
    #   Then sort them by their views
    video_in_cluster = merged_df.query(f"cluster_id == {cluster_id}")\
                            .sort_values(by=metric_to_sort, ascending=False)
    
    # Iterate through each video in the cluster
    for i, video in video_in_cluster.iterrows():
        channelTitle = video['channelTitle']
        videoTitle = video['title']
        
        # If the channel has already been recommended, skip it
        if channelTitle in set_of_channels:
            continue
        
        # Otherwise, add it to the list of recommended channels
        if len(recommended_videos.columns) == 2:
            recommended_videos.loc[len(recommended_videos)] = [channelTitle, videoTitle]
        else: # !USING THE BELOW CODE FOR TESTING
            recommended_videos.loc[len(recommended_videos)] = [channelTitle, videoTitle, video['viewCount']]
        
        # Add the channel to the set
        set_of_channels.add(channelTitle)
        
        # If we have enough channels, stop
        if len(recommended_videos) >= top_n:
            break        
    
    return recommended_videos

# %% [markdown]
# Show some results

# %%
# Display the results
for i, title in enumerate(new_data):
    recommended_videos = _recommend_top_n_videos(pred_labels[i], top_n=5)
    print(f"Recommended videos for '{title}':")
    print(recommended_videos)
    print("--------------------------------------\n")
# Out:
# Recommended videos for 'Tech news and updates':
#         channelTitle                                              title
# 0    Google DeepMind  AlphaGo - The Movie | Full award-winning docum...
# 1          Joma Tech  a day in the life of an engineer working from ...
# 2        3Blue1Brown  But what is a Fourier series?  From heat flow ...
# 3        Lex Fridman  Jordan Peterson: Life, Death, Power, Fame, and...
# 4  Two Minute Papers  OpenAI Plays Hide and Seek…and Breaks The Game! 🤖
# --------------------------------------
#
# Recommended videos for 'Learn Python in fast and easy way':
#           channelTitle                                              title
# 0        Tech With Tim  12 Hour Coding Livestream - Creating an Online...
# 1              CS Dojo  Python Tutorial for Absolute Beginners #1 - Wh...
# 2  TechWorld with Nana  Python Tutorial for Beginners - Learn Python i...
# 3        Corey Schafer       Python OOP Tutorial 1: Classes and Instances
# 4          Keith Galli  Complete Python Pandas Data Science Tutorial! ...
# --------------------------------------
#
# Recommended videos for 'Machine learning explained in 5 minutes':
#                   channelTitle  \
# 0                      sentdex
# 1                    Joma Tech
# 2                   codebasics
# 3               Great Learning
# 4  StatQuest with Josh Starmer
#
#                                                title
# 0  Practical Machine Learning Tutorial with Pytho...
# 1  Interview With My Brother Who Sold His Startup...
# 2  Reality behind data science, machine learning ...
# 3  Machine Learning with Python | Machine Learnin...
# 4   Machine Learning Fundamentals: Bias and Variance
# --------------------------------------
#
# Recommended videos for 'How to become a Data Analyst':
#          channelTitle                                              title
# 0       Luke Barousse  Become a DATA ANALYST with NO degree?!? The Go...
# 1  Shashank Kalanithi  Day in the Life of a Data Analyst - SurveyMonk...
# 2          Stefanovic  FASTEST Way to Become a Data Analyst and ACTUA...
# 3             CS Dojo  Data Structures & Algorithms #1 - What Are Dat...
# 4            DataCamp                   Turn Your Team into Data Masters
# --------------------------------------

# %% [markdown]
# ##### Recommend top `n` tags in the same cluster

# %%
def _recommend_top_n_tags(cluster_id, top_n: int = 10) -> np.ndarray:
    tags_in_cluster = merged_df.query(f"cluster_id == {cluster_id}")
    tags_in_cluster = \
        tags_in_cluster.sort_values(by='viewCount', ascending=False,)\
            ['tags'].head(2*top_n)

    # Create a dataframe to store the one-hot encoding of tags
    one_hot_df = tags_in_cluster.str.get_dummies(sep='|')
    if "(notag)" in one_hot_df.columns:
        one_hot_df = one_hot_df.drop("(notag)",axis=1)
    # Sum the one-hot encoding of tags
    all_tags = one_hot_df.sum().sort_values(ascending=False).head(2*top_n)

    # # Preprocess all tags
    preprocessed_tags = pd.Series(all_tags.index).apply(preprocess_text)

    # Get only unique tags
    unique_tags = pd.unique(preprocessed_tags)
    return unique_tags

# %% [markdown]
# Show some results

# %%
# Display the results
for i, title in enumerate(new_data):
    recommended_tags = _recommend_top_n_tags(pred_labels[i], top_n=5)
    print(f"Recommended tags for '{title}':")
    print("\"" + "\", \"".join(recommended_tags.tolist()) + "\"")
    print("--------------------------------------\n")
# Out:
# Recommended tags for 'Tech news and updates':
# "blue brown", "three blue one brown", "bb", "brownblue", "brown blue", "three brown one blue", "mathematics", "software engineer", "ai", "vlog"
# --------------------------------------
#
# Recommended tags for 'Learn Python in fast and easy way':
# "python tutorial", "python", "tech tim", "python tutorial beginners", "python beginners", "python basics", "programming", "getting started python", "python programming", "python complete course"
# --------------------------------------
#
# Recommended tags for 'Machine learning explained in 5 minutes':
# "artificial intelligence", "machine learning", "python", "deep learning", "supervised machine learning", "data science", "machine learning python", "statistics", "python machine learning tutorial"
# --------------------------------------
#
# Recommended tags for 'How to become a Data Analyst':
# "python", "data science", "data science tutorial", "r programming", "data analyst", "power bi", "spreadsheets", "get data analyst job without experience", "get data analyst job fresher", "get data analyst job"
# --------------------------------------

# %% [markdown]
# # ----- break -----

# %%
train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 train
#
# NameError: name 'train' is not defined

# %%
def my_clustering(s, n_clusters, print_clusters=False): 
    text_values = s

    # Convert text to numerical data using TF-IDF
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(text_values)

    # Choose the number of clusters (you may need to adjust this based on your data)
    num_clusters = n_clusters

    # Apply K-Means clustering
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(X)

    # Print the clusters
    if print_clusters:
        # Get cluster labels
        cluster_labels = kmeans.labels_
        for i in range(num_clusters):
            print(f"Cluster {i + 1}:")
            cluster_texts = np.array(text_values)[cluster_labels == i]
            for text in cluster_texts:
                print(f"  - {text}")
            print("\n")
    
    return kmeans, vectorizer

# %% [markdown]
# ## Clustering tags

# %% [markdown]
# # -------------------- BREAK --------------------

# %% [markdown]
# ## Feature engineering

# %%
target = "viewCount"
X = clean_df.copy()
X.drop(target, axis=1, inplace=True)
y = clean_df[target].copy()

cat_cols = [col for col in X.columns if X[col].dtype == "object"]
from sklearn.preprocessing import LabelEncoder
for col in cat_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    # X_val[col] = le.transform(X_val[col])
    # X_test[col] = le.transform(X_test[col])

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape

# %% [markdown]
# ## Training model and evaluation

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ## Evaluation

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ## Prediction

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ## Results analysis

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Your conclusion**
